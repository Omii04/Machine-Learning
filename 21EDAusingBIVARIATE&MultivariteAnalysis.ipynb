# %%
import pandas as pd          
import seaborn as sbn  
import matplotlib.pyplot as plt

# %%
titanic=pd.read_csv(r"C:\Users\om420\Downloads\titanic_sample_campusx.csv")
titanic
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         1       1
# 7            8         0       3
# 8            9         1       2
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
#scatterplot (Numerical-Numerical)

sbn.scatterplot(x=titanic['Pclass'],y=titanic['Age'],hue=titanic['Fare'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
#Barplot (Numerical-Categorical)
sbn.barplot(x=titanic['Pclass'],y=titanic['Fare'],hue=titanic['Sex'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
#Boxplot (Numerical-categorical)

sbn.boxplot(x=titanic['Pclass'],y=titanic['Age'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
# Distplot (Numerical-Categorical)
sbn.distplot(titanic['Survived']==0,hist=False)
sbn.distplot(titanic['Survived']==1,hist=False)
# Out:
# C:\Users\om420\AppData\Local\Temp\ipykernel_3012\2604938844.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sbn.distplot(titanic['Survived']==0,hist=False)
# C:\Users\om420\AppData\Local\Temp\ipykernel_3012\2604938844.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
# Heatmap (categorical-categorical)
sbn.heatmap(pd.crosstab(titanic['Sex'],titanic['Survived']))
(titanic.groupby('Sex').mean('Survived')*100)
# Out:
#         PassengerId  Survived  Pclass     Age  SibSp  Parch      Fare
# Sex
# female        560.0     100.0   180.0  2800.0   60.0   40.0  3470.248
# male          540.0      20.0   260.0  2825.0   80.0   20.0  1933.916

# %%
#Clustermap (Categorical-categorical)

# %%
#Pairplot
sbn.pairplot(titanic)

# %%
#Lineplot(Numerical-Numerical),(X-axis should be time based like date,year)
sbn.lineplot(titanic['Fare'])
# Out:
# <Axes: ylabel='Fare'>
