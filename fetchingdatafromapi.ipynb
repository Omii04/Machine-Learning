# %%
import pandas as pd    
import requests

# %%
respons=requests.get("https://www.omdbapi.com/?t=Inception&apikey=e620f3b2")
respons
# Out:
# <Response [200]>

# %%
d=respons.json()

print(d)
# Out:
# {'Title': 'Inception', 'Year': '2010', 'Rated': 'PG-13', 'Released': '16 Jul 2010', 'Runtime': '148 min', 'Genre': 'Action, Adventure, Sci-Fi', 'Director': 'Christopher Nolan', 'Writer': 'Christopher Nolan', 'Actors': 'Leonardo DiCaprio, Joseph Gordon-Levitt, Elliot Page', 'Plot': 'A thief who steals corporate secrets through the use of dream-sharing technology is given the inverse task of planting an idea into the mind of a C.E.O., but his tragic past may doom the project and his team to disaster.', 'Language': 'English, Japanese, French', 'Country': 'United States, United Kingdom', 'Awards': 'Won 4 Oscars. 159 wins & 220 nominations total', 'Poster': 'https://m.media-amazon.com/images/M/MV5BMjAxMzY3NjcxNF5BMl5BanBnXkFtZTcwNTI5OTM0Mw@@._V1_SX300.jpg', 'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.8/10'}, {'Source': 'Rotten Tomatoes', 'Value': '87%'}, {'Source': 'Metacritic', 'Value': '74/100'}], 'Metascore': '74', 'imdbRating': '8.8', 'imdbVotes': '2,743,035', 'imdbI
# ...

# %%
df = pd.DataFrame(d)
#df.to_csv('movie.csv',index=False)

# %%
pip install pandas requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df.head(10)
# Out:
#        Title  Year  Rated     Released  Runtime                      Genre  \
# 0  Inception  2010  PG-13  16 Jul 2010  148 min  Action, Adventure, Sci-Fi
# 1  Inception  2010  PG-13  16 Jul 2010  148 min  Action, Adventure, Sci-Fi
# 2  Inception  2010  PG-13  16 Jul 2010  148 min  Action, Adventure, Sci-Fi
#
#             Director             Writer  \
# 0  Christopher Nolan  Christopher Nolan
# 1  Christopher Nolan  Christopher Nolan
# 2  Christopher Nolan  Christopher Nolan
#
#                                               Actors  \
# 0  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...
# 1  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...
# 2  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...
#
#                                                 Plot  ... Metascore  \
# 0  A thief who steals corporate secrets through t...  ...        74
# 1  A thief who steals corporate secrets through t...  ...        74
# 2  A thief who steals corporate secrets through t...  ...        74
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 25 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       3 non-null      object
#  1   Year        3 non-null      object
#  2   Rated       3 non-null      object
#  3   Released    3 non-null      object
#  4   Runtime     3 non-null      object
#  5   Genre       3 non-null      object
#  6   Director    3 non-null      object
#  7   Writer      3 non-null      object
#  8   Actors      3 non-null      object
#  9   Plot        3 non-null      object
#  10  Language    3 non-null      object
#  11  Country     3 non-null      object
#  12  Awards      3 non-null      object
#  13  Poster      3 non-null      object
#  14  Ratings     3 non-null      object
#  15  Metascore   3 non-null      object
#  16  imdbRating  3 non-null      object
#  17  imdbVotes   3 non-null      object
#  18  imdbID      3 non-null      object
# ...

# %%
df.to_csv('movie.csv',index=False)
df
# Out:
#        Title  Year  Rated     Released  Runtime                      Genre  \
# 0  Inception  2010  PG-13  16 Jul 2010  148 min  Action, Adventure, Sci-Fi
# 1  Inception  2010  PG-13  16 Jul 2010  148 min  Action, Adventure, Sci-Fi
# 2  Inception  2010  PG-13  16 Jul 2010  148 min  Action, Adventure, Sci-Fi
#
#             Director             Writer  \
# 0  Christopher Nolan  Christopher Nolan
# 1  Christopher Nolan  Christopher Nolan
# 2  Christopher Nolan  Christopher Nolan
#
#                                               Actors  \
# 0  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...
# 1  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...
# 2  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...
#
#                                                 Plot  ... Metascore  \
# 0  A thief who steals corporate secrets through t...  ...        74
# 1  A thief who steals corporate secrets through t...  ...        74
# 2  A thief who steals corporate secrets through t...  ...        74
#
# ...

# %%
pip install ydata-profiling
# Out:
# ...
#   Using cached visions-0.8.1-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# ...
#   Using cached typeguard-4.4.4-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached ImageHash-4.3.1-py2.py3-none-any.whl.metadata (8.0 kB)
# ...
#   Using cached dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# ...
#   Using cached puremagic-1.30-py3-none-any.whl.metadata (5.8 kB)
# ...
# Using cached ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ---------- ----------------------------- 2.1/8.0 MB 9.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.5/8.0 MB 11.1 MB/s eta 0:00:01
#    --------------------------------- ------ 6.8/8.0 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 11.1 MB/s eta 0:00:00
# Using cached multimethod-1.12-py3-none-any.whl (10 kB)
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
# ...
