# %%
import numpy as np                              
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv(r"C:\Users\om420\Downloads\archive (1)\Wine.csv",usecols=['Alcohol','Malic_Acid'])
df.head()
# Out:
#    Alcohol  Malic_Acid
# 0    14.23        1.71
# 1    13.20        1.78
# 2    13.16        2.36
# 3    14.37        1.95
# 4    13.24        2.59

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Alcohol     178 non-null    float64
#  1   Malic_Acid  178 non-null    float64
# dtypes: float64(2)
# memory usage: 2.9 KB

# %%
sns.distplot(df['Alcohol'])
# Out:
# C:\Users\om420\AppData\Local\Temp\ipykernel_343768\3372989474.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Alcohol'])
# <Axes: xlabel='Alcohol', ylabel='Density'>

# %%
sns.distplot(df['Malic_Acid'])
# Out:
# C:\Users\om420\AppData\Local\Temp\ipykernel_343768\2525838296.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Malic_Acid'])
# <Axes: xlabel='Malic_Acid', ylabel='Density'>

# %%
scaler=MinMaxScaler()

# %%
X_train,X_test,y_train,y_test=train_test_split(df[['Alcohol']],df['Malic_Acid'],test_size=0.2,random_state=42)

# %%
X_train_TRF=scaler.fit_transform(X_train)
X_test_TRF=scaler.fit_transform(X_test)

# %%
sns.distplot(X_test_TRF)
# Out:
# C:\Users\om420\AppData\Local\Temp\ipykernel_343768\3039356070.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_test_TRF)
# <Axes: ylabel='Density'>

# %%
# Original
plt.subplot(1,2,1)
sns.histplot(df['Malic_Acid'], kde=True, color="blue")
plt.title("Original Malic Acid")

# Scaled
plt.subplot(1,2,2)
sns.histplot(X_test_TRF, kde=True, color="green")
plt.title("Scaled Malic Acid (MinMaxScaler)")

plt.show()
