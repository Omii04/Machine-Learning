# %%
import pandas as pd   
import seaborn as sns   
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df=pd.read_csv(r)
#       2 df.head()
#
# NameError: name 'r' is not defined

# %%
sns.countplot(df['Math'])
# Out:
# <Axes: ylabel='count'>

# %%
#piechart
df['Toss'].value_counts().plot(kind='pie',autopct='%.2f%%')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 #piechart
# ----> 2 df['Toss'].value_counts().plot(kind='pie',autopct='%.2f%%')
#
# NameError: name 'df' is not defined

# %%
#hostogram
plt.hist(df['Year'],bins=20)
# Out:
# (array([ 6.,  8., 14.,  8.,  0., 14., 14.,  0., 14.,  0., 26.,  0., 26.,
#         14., 14., 22., 22., 26.,  0., 26.]),
#  array([1984. , 1985.9, 1987.8, 1989.7, 1991.6, 1993.5, 1995.4, 1997.3,
#         1999.2, 2001.1, 2003. , 2004.9, 2006.8, 2008.7, 2010.6, 2012.5,
#         2014.4, 2016.3, 2018.2, 2020.1, 2022. ]),
#  <BarContainer object of 20 artists>)

# %%
sns.displot(df['Player Of The Match'],kde=9)

# %%
sns.boxplot(df['Player Of The Match'])
# Out:
# <Axes: ylabel='Player Of The Match'>

# %%
df['Toss'].max()
# Out:
# 'win'

# %%
#scatterplot
sns.scatterplot(x=df['Toss'],y=df['Selection'],hue='Result')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 2
#       1 #scatterplot
# ----> 2 sns.scatterplot(x=df['Toss'],y=df['Selection'],hue='Result')
#
# File e:\Anaconda\Lib\site-packages\seaborn\relational.py:615, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     606 def scatterplot(
#     607     data=None, *,
#     608     x=None, y=None, hue=None, size=None, style=None,
#    (...)
#     612     **kwargs
#     613 ):
# --> 615     p = _ScatterPlotter(
#     616         data=data,
#     617         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#     618         legend=legend
#     619     )
#     621     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     622     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# ...

# %%
titanic=pd.read_csv(r"C:\Users\om420\Downloads\titanic_sample_campusx.csv")
titanic
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         1       1
# 7            8         0       3
# 8            9         1       2
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
#Barplot
sns.barplot(x=titanic['Pclass'],y=titanic['Fare'],hue=titanic['Sex'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
#Boxplot
sns.boxplot(x=titanic['Sex'],y=titanic['Age'],hue=titanic['Survived'])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
#distplot
sns.distplot(x=titanic['Survived']==0,hist=False,color='yellow')
sns.distplot(x=titanic['Survived']==1,hist=False,color='green')
# Out:
# C:\Users\om420\AppData\Local\Temp\ipykernel_304840\3458485365.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=titanic['Survived']==0,hist=False,color='yellow')
# C:\Users\om420\AppData\Local\Temp\ipykernel_304840\3458485365.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
#heatmap
sns.heatmap(pd.crosstab(titanic['Pclass'],titanic['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>
